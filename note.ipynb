# %%
# %pip install tensorboardX
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 6.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install cppimport
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for cppimport: filename=cppimport-22.8.2-py3-none-any.whl size=17735 sha256=e67f407af45a4dd5a1e495b526e70300a06c1e93b2f38bcc07bcc0a7ae12030c
#   Stored in directory: /root/.cache/pip/wheels/1b/74/c3/da98286e4d715a502b9ecbc9d439406597959debe0a0d0a079
# Successfully built cppimport
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from os import chdir
chdir("/kaggle/input/lightgcn-data-python-modules/code/")
# !python main.py --epochs=1000 --decay=1e-4 --lr=0.001 --layer=3 --seed=2020 --tensorboard=1 --dataset="amazon-electronic" --topks="[20]" --recdim=64
# Out:
# Cpp extension not loaded
# >>SEED: 2020
# loading [../data/amazon-electronic]
# 282362 interactions for training
# 111553 interactions for testing
# amazon-electronic Sparsity : 0.000261327578810023
# amazon-electronic is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 64,
#  'lightGCN_n_layers': 3,
#  'lr': 0.001,
#  'multicore': 0,
#  'pretrain': 0,
#  'test_u_batch_size': 100}
# cores for test: 2
# comment: lgn
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [20]
# using bpr loss
# ===========end===================
# use NORMAL distribution initilizer
# loading adjacency matrix
# successfully loaded...
# ...
